# %% [markdown]
# A package is a way to organize related Python modules into a directory structure so your code becomes easier to manage, reuse, and maintain
# A package is a folder that contains multiple Python modules and a special file called __init__.py.

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np

# %%
from package.maths import addition
print(addition(3,5))
# Out:
# 8

# %%
from package import maths
maths.addition(2,3)
# Out:
# 5
