# %% [markdown]
# "OOPS"
#
# Class : A class is a blueprint (design) for creating objects.
# It defines what data and actions an object will have.
#
# Object : An object is a real thing created from a class.
# It is an instance of a class.
#
# Instance Variable: An instance variable is a variable that belongs to an object.
# Each object has its own copy.
#
# Instance Method:
# A method that works on an object’s data and needs the object to be created first.

# %%
class Car:
    pass
audi = Car()
print(type(audi))
audi.windows=4
print(audi.windows)
# Out:
# <class '__main__.Car'>
# 4

# %%
class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def bark(self):
         print(f"{self.name} is barking")
a1 = Dog("bruny",2)
a2 = Dog("lucy",4)
print(a1.name)
a1.bark()
a2.bark()
# Out:
# bruny
# bruny is barking
# lucy is barking

# %%
class Bank:
    def __init__(self,name,balance=0):
        self.name = name
        self.balance = balance
    def deposit(self,amount):
        self.balance+=amount
        print(f"Deposited={amount}, total balance={self.balance}")
    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient funds")
        else:
            self.balance-=amount
            print(f"WIthdrawn{amount}, total balance={self.balance}")
a1 = Bank("aru",1000)
a1.deposit(1200)
a1.withdraw(400)
# Out:
# Deposited=1200, total balance=2200
# WIthdrawn400, total balance=1800

# %% [markdown]
# Inheritance
#
# Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows a class to inherit attributes and methods from another class.

# %%
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    
    def drive(self):
        print(f"The person will drive the {self.enginetype} car ")
car1=Car(4,5,"petrol")
car1.drive()
# Out:
# The person will drive the petrol car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving = is_selfdriving
    def self_driving(self):
        print(f"Tesla supports self driving : {self.is_selfdriving}")

tesla1=Tesla(4,5,"electric",True)
tesla1.self_driving()
tesla1.drive()
# Out:
# Tesla supports self driving : True
# The person will drive the electric car

# %% [markdown]
# #Multiple Inheritance

# %%
class Animal:
    def __init__(self,name):
        self.name=name

    def speak(self):
        print("Subclass must implement this method")

class Pet:
    def __init__(self, owner):
        self.owner = owner

class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)

    def speak(self):
        return f"{self.name} say woof"
    
dog=Dog("Buddy","Krish")
print(dog.speak())
print(f"Owner:{dog.owner}")
# Out:
# Buddy say woof
# Owner:Krish
